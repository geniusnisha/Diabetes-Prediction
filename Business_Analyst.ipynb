# %% [markdown]
# <a href="https://colab.research.google.com/github/geniusnisha/Diabetes-Prediction/blob/main/Business_Analyst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ydata-profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.2/356.2 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 20.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 28.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 75.8 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=b0dd6fa202fe3d60f699531bfb4475c6b709222d0add1bf930b07d2f8e0c05e0
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %%
# !pip install pandas-profiling

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport

# %%
data=pd.read_csv('/content/drive/MyDrive/Business Analyst -ABC University.csv')

# %%
data.head(10)
# Out:
#                 Name      Mobile Lead Origin Country        State     City  \
# 0          Ram Yadav  9830******         API   India  West Bengal  Kolkata
# 1    Anamika Bairagi  7439******         API   India  West Bengal  Barasat
# 2         Puja Singh  7003******         API   India  West Bengal  Kolkata
# 3       Jhuma Haldar  9831******         API   India  West Bengal  Kolkata
# 4        Rajan Kumar  9128******         API   India  West Bengal  Kolkata
# 5   Deepshikha kamti  6291******         API   India  West Bengal  Kolkata
# 6       Shivang soni  9674******         API   India  West Bengal  Kolkata
# 7        Kajol Rathi  9748******         API   India  West Bengal  Kolkata
# 8  Sayon chakraborty  9804******         API   India  West Bengal  Kolkata
# 9   Sk Zahira Khatun  9831******         API   India  West Bengal  Kolkata
#
#   Instance Instance Date        Campaign    Lead Stage  ...  \
# 0  Primary     10/9/2023     Meta/85/API     Untouched  ...
# ...

# %%
data.tail(5)
# Out:
#                     Name      Mobile Lead Origin Country        State  \
# 31599        Dhannu Raja  8340******         API   India        Bihar
# 31600    ROHIN DAS SHEKH  8334******         API   India  West Bengal
# 31601  Reena Das Debnath  9064******         API   India  West Bengal
# 31602              Virat  9568******      Online   India    Jharkhand
# 31603             Vishal  7415******      Online   India  West Bengal
#
#             City Instance Instance Date            Campaign    Lead Stage  \
# 31599  Madhepura  Primary     2/21/2023      Meta/92_RV/API     NR Closed
# 31600     Howrah  Primary     2/21/2023      Meta/92_RV/API     NR Closed
# 31601    Kolkata  Primary     2/21/2023      Meta/92_RV/API  Disqualified
# 31602  Azadnagar  Primary     2/21/2023  Meta/TestLP/Online  Disqualified
# 31603    Kolkata  Primary     2/21/2023  Meta/TestLP/Online  Disqualified
#
#        ... Mobile Verification Status Registration Device  \
# ...

# %%
data.tail(5)
# Out:
#                     Name      Mobile Lead Origin Country        State  \
# 31599        Dhannu Raja  8340******         API   India        Bihar
# 31600    ROHIN DAS SHEKH  8334******         API   India  West Bengal
# 31601  Reena Das Debnath  9064******         API   India  West Bengal
# 31602              Virat  9568******      Online   India    Jharkhand
# 31603             Vishal  7415******      Online   India  West Bengal
#
#             City Instance Instance Date            Campaign    Lead Stage  \
# 31599  Madhepura  Primary     2/21/2023      Meta/92_RV/API     NR Closed
# 31600     Howrah  Primary     2/21/2023      Meta/92_RV/API     NR Closed
# 31601    Kolkata  Primary     2/21/2023      Meta/92_RV/API  Disqualified
# 31602  Azadnagar  Primary     2/21/2023  Meta/TestLP/Online  Disqualified
# 31603    Kolkata  Primary     2/21/2023  Meta/TestLP/Online  Disqualified
#
#        ... Mobile Verification Status Registration Device  \
# ...

# %%
data.describe()
# Out:
#        Form Initiated  Paid Applications  Submitted Applications
# count    31604.000000       31604.000000            31604.000000
# mean         0.040564           0.013543                0.013479
# std          0.199198           0.115584                0.115317
# min          0.000000           0.000000                0.000000
# 25%          0.000000           0.000000                0.000000
# 50%          0.000000           0.000000                0.000000
# 75%          0.000000           0.000000                0.000000
# max          2.000000           1.000000                1.000000

# %%
data.isnull().sum()
# registration device has 30912 null value
# Out:
# Name                              0
# Mobile                            0
# Lead Origin                       0
# Country                           0
# State                             0
# City                              0
# Instance                          0
# Instance Date                     0
# Campaign                          0
# Lead Stage                        0
# Lead Status                       0
# Email Verification Status         0
# Mobile Verification Status        0
# Registration Device           30912
# Course                            0
# Specialization                    0
# Campus                            0
# Last Lead Activity Date           0
# Form Initiated                    0
# Paid Applications                 0
# Submitted Applications            0
# Enrolment Status                  0
# dtype: int64

# %%
data.dtypes
# Out:
# Name                          object
# Mobile                        object
# Lead Origin                   object
# Country                       object
# State                         object
# City                          object
# Instance                      object
# Instance Date                 object
# Campaign                      object
# Lead Stage                    object
# Lead Status                   object
# Email Verification Status     object
# Mobile Verification Status    object
# Registration Device           object
# Course                        object
# Specialization                object
# Campus                        object
# Last Lead Activity Date       object
# Form Initiated                 int64
# Paid Applications              int64
# Submitted Applications         int64
# Enrolment Status              object
# dtype: object

# %%
New_data = data.dropna(subset=['Registration Device'])
# Remove null value of Registration device

# %%
New_data.head(5)
# Out:
#                     Name      Mobile Lead Origin Country        State  \
# 279       Sneha Adhikary  6290******      Online   India  West Bengal
# 344        Rahima khatun  7318******      Online   India  West Bengal
# 1810      ABHISHEK KUMAR  7352******      Online   India        Bihar
# 1826  Kankan Chakraborty  7584******      Online   India  West Bengal
# 1830      Srishti Kumari  9060******      Online   India        Bihar
#
#            City Instance Instance Date               Campaign    Lead Stage  \
# 279     Kolkata  Primary     10/4/2023  Meta/aTextlink/Online     Qualified
# 344    Jangipur  Primary     10/3/2023    Meta/Emailer/Online     Untouched
# 1810      Patna  Primary     9/12/2023    Meta/Emailer/Online  Disqualified
# 1826    Kolkata  Primary     9/12/2023    Meta/Emailer/Online  Disqualified
# 1830  Madhepura  Primary     9/12/2023    Meta/Emailer/Online  Disqualified
#
#       ... Mobile Verification Status Registration Device  \
# ...

# %%
New_data.isnull().sum()
# Out:
# Name                          0
# Mobile                        0
# Lead Origin                   0
# Country                       0
# State                         0
# City                          0
# Instance                      0
# Instance Date                 0
# Campaign                      0
# Lead Stage                    0
# Lead Status                   0
# Email Verification Status     0
# Mobile Verification Status    0
# Registration Device           0
# Course                        0
# Specialization                0
# Campus                        0
# Last Lead Activity Date       0
# Form Initiated                0
# Paid Applications             0
# Submitted Applications        0
# Enrolment Status              0
# dtype: int64

# %% [markdown]
# GENERATE A REPORT

# %%
profile=ProfileReport(New_data)

# %%
profile.to_file(output_file="ABCUniversity.html")
# This is html file has Report overview
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/utils/dataframe.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"index": "df_index"}, inplace=True)
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
